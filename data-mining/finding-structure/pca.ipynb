# %% [markdown]
# # Principal Component Analysis (PCA)
#
# PCA is a dimensionality reduction technique. It can reduce the number of features in a dataset by projecting the data onto a lower dimensional space. The idea is that it preserves the structure of the data as much as possible, by preserving what matters the most. Technically, it finds a lower dimensional projection of the dataset which maximizes the information contained within the dataset (the definition of "information" is purposfully vague).
#
# Intuitively: imagine you have a 3D dataset with 3 features. You can visualize it in a 3D space. Now imagine you want to reduce the number of features to 2. You can project the data onto a 2D space. This is what PCA does. It's a bit like taking the best 2D picture of the Eiffel Tower.

# %% [markdown]
# <div class="sketchfab-embed-wrapper"> <iframe title="Eiffel Tower model 3D with best quality" frameborder="0" allowfullscreen mozallowfullscreen="true" webkitallowfullscreen="true" allow="autoplay; fullscreen; xr-spatial-tracking" xr-spatial-tracking execution-while-out-of-viewport execution-while-not-rendered web-share src="https://sketchfab.com/models/c3391c293e70471e9a112f7855adcf2f/embed"> </iframe> <p style="font-size: 13px; font-weight: normal; margin: 5px; color: #4A4A4A;"> <a href="https://sketchfab.com/3d-models/eiffel-tower-model-3d-with-best-quality-c3391c293e70471e9a112f7855adcf2f?utm_medium=embed&utm_campaign=share-popup&utm_content=c3391c293e70471e9a112f7855adcf2f" target="_blank" rel="nofollow" style="font-weight: bold; color: #1CAAD9;"> Eiffel Tower model 3D with best quality </a> by <a href="https://sketchfab.com/shatlykxfree?utm_medium=embed&utm_campaign=share-popup&utm_content=c3391c293e70471e9a112f7855adcf2f" target="_blank" rel="nofollow" style="font-weight: bold; color: #1CAAD9;"> shatlykxfree </a> on <a href="https://sketchfab.com?utm_medium=embed&utm_campaign=share-popup&utm_content=c3391c293e70471e9a112f7855adcf2f" target="_blank" rel="nofollow" style="font-weight: bold; color: #1CAAD9;">Sketchfab</a></p></div>

# %% [markdown]
# PCA has several applications:
#
# - Visualization: PCA can be used to visualize high dimensional data in 2 or 3 dimensions.
# - Speeding up Machine Learning (ML) training: PCA can be used to speed up ML training by reducing the number of features.
# - Collaborative filtering: PCA can be used in collaborative filtering applications.
# - Anomaly detection: PCA can be used to detect anomalies in datasets.
# - Simplify: linear regression applied to PCA data is a form of shrinkage (see [principal component regression](https://www.wikiwand.com/en/Principal_component_regression))
#
# In this notebook, we will use PCA for noise reduction and visualization.

# %% [markdown]
# We'll be analyzing an emission factor database. These are the environmental impacts of goods and services. In particular, we'll be looking at the emission factors of different food items. The data is from the [Agribalyse](https://agribalyse.ademe.fr/app) database. The raw data can be downloaded from the ADEME website, [here](https://data.ademe.fr/datasets?topics=TQJGtxm2_).

# %%
import pandas as pd

food = pd.read_csv('../../data/agribalyse-31-synthese.csv')
indicators = {
    'Changement climatique': 'Changement climatique',
    'Appauvrissement de la couche d\'ozone': 'Couche d\'ozone',
    'Rayonnements ionisants': 'Rayonnements',
    'Formation photochimique d\'ozone': 'Formation d\'ozone',
    'Particules fines': 'Particules fines',
    'Effets toxicologiques sur la santé humaine : substances non-cancérogènes': 'Effets non-cancéreux',
    'Effets toxicologiques sur la santé humaine : substances cancérogènes': 'Effets cancéreux',
    'Acidification terrestre et eaux douces': 'Acidification terrestre/eau douce',
    'Eutrophisation eaux douces': 'Eutrophisation eau douce',
    'Eutrophisation marine': 'Eutrophisation marine',
    'Eutrophisation terrestre': 'Eutrophisation terrestre',
    'Écotoxicité pour écosystèmes aquatiques d\'eau douce': 'Écotoxicité eau douce',
    'Utilisation du sol': 'Utilisation sol',
    'Épuisement des ressources eau': 'Épuisement ressources eau',
    'Épuisement des ressources énergétiques': 'Épuisement ressources énergétiques',
    'Épuisement des ressources minéraux': 'Épuisement ressources minéraux'
}
food = food.rename(columns=indicators)
food = food.set_index('LCI Name')
food.head()
# Out:
#                                                    Code AGB  Code CIQUAL  \
# LCI Name
# Seaweed, agar, raw                                    11084        11084
# Garlic, powder, dried                                 11023        11023
# Garlic, fresh                                         11000        11000
# Dill, fresh                                           11093        11093
# Sea lettuce (Enteromorpha sp.), dried or dehydr...    20995        20995
#
#                                                                           Groupe d'aliment  \
# LCI Name
# Seaweed, agar, raw                                  aides culinaires et ingrédients divers
# Garlic, powder, dried                               aides culinaires et ingrédients divers
# Garlic, fresh                                       aides culinaires et ingrédients divers
# Dill, fresh                                         aides culinaires et ingrédients divers
# Sea lettuce (Enteromorpha sp.), dried or dehydr...  aides culinaires et ingrédients divers
#
#                                                    Sous-groupe d'aliment  \
# LCI Name
# Seaweed, agar, raw                                                algues
# Garlic, powder, dried                                             herbes
# Garlic, fresh                                                     herbes
# Dill, fresh                                                       herbes
# Sea lettuce (Enteromorpha sp.), dried or dehydr...                algues
#
#                                                                            Nom du Produit en Français  \
# LCI Name
# Seaweed, agar, raw                                                                  Agar (algue), cru
# Garlic, powder, dried                                                               Ail séché, poudre
# Garlic, fresh                                                                                Ail, cru
# Dill, fresh                                                                              Aneth, frais
# Sea lettuce (Enteromorpha sp.), dried or dehydr...  Ao-nori (Enteromorpha sp.), séchée ou déshydratée
#
#                                                     code saison  code avion  \
# LCI Name
# Seaweed, agar, raw                                            2           0
# Garlic, powder, dried                                         2           0
# Garlic, fresh                                                 2           0
# Dill, fresh                                                   2           0
# Sea lettuce (Enteromorpha sp.), dried or dehydr...            2           0
#
#                                                          Livraison  \
# LCI Name
# Seaweed, agar, raw                                  Ambiant (long)
# Garlic, powder, dried                               Ambiant (long)
# Garlic, fresh                                       Ambiant (long)
# Dill, fresh                                         Ambiant (long)
# Sea lettuce (Enteromorpha sp.), dried or dehydr...  Ambiant (long)
#
#                                                    Matériau d'emballage  \
# LCI Name
# Seaweed, agar, raw                                                 LDPE
# Garlic, powder, dried                                             Verre
# Garlic, fresh                                           Pas d'emballage
# Dill, fresh                                                        LDPE
# Sea lettuce (Enteromorpha sp.), dried or dehydr...                 LDPE
#
#                                                            Préparation   DQR  \
# LCI Name
# Seaweed, agar, raw                                  Pas de préparation  2.99
# Garlic, powder, dried                               Pas de préparation  4.11
# Garlic, fresh                                       Pas de préparation  3.54
# Dill, fresh                                         Pas de préparation  3.75
# Sea lettuce (Enteromorpha sp.), dried or dehydr...  Pas de préparation  2.99
#
#                                                     Score unique EF  \
# LCI Name
# Seaweed, agar, raw                                         1.226025
# Garlic, powder, dried                                      0.103513
# Garlic, fresh                                              0.064652
# Dill, fresh                                                0.131581
# Sea lettuce (Enteromorpha sp.), dried or dehydr...         1.226025
#
#                                                     Changement climatique  \
# LCI Name
# Seaweed, agar, raw                                               6.745806
# Garlic, powder, dried                                            0.750274
# Garlic, fresh                                                    0.358043
# Dill, fresh                                                      0.813436
# Sea lettuce (Enteromorpha sp.), dried or dehydr...               6.745806
#
#                                                     Couche d'ozone  \
# LCI Name
# Seaweed, agar, raw                                    1.017147e-06
# Garlic, powder, dried                                 1.229332e-07
# Garlic, fresh                                         5.483998e-08
# Dill, fresh                                           6.268829e-08
# Sea lettuce (Enteromorpha sp.), dried or dehydr...    1.017147e-06
#
#                                                     Rayonnements  \
# LCI Name
# Seaweed, agar, raw                                     11.050022
# Garlic, powder, dried                                   0.172269
# Garlic, fresh                                           0.143971
# Dill, fresh                                             0.141342
# Sea lettuce (Enteromorpha sp.), dried or dehydr...     11.050022
#
#                                                     Formation d'ozone  \
# LCI Name
# Seaweed, agar, raw                                           0.038875
# Garlic, powder, dried                                        0.002936
# Garlic, fresh                                                0.001081
# Dill, fresh                                                  0.002559
# Sea lettuce (Enteromorpha sp.), dried or dehydr...           0.038875
#
#                                                     Particules fines  \
# LCI Name
# Seaweed, agar, raw                                      7.172887e-07
# Garlic, powder, dried                                   8.262876e-08
# Garlic, fresh                                           2.344885e-08
# Dill, fresh                                             6.896720e-08
# Sea lettuce (Enteromorpha sp.), dried or dehydr...      7.172887e-07
#
#                                                     Effets non-cancéreux  \
# LCI Name
# Seaweed, agar, raw                                          4.771949e-08
# Garlic, powder, dried                                       9.281982e-09
# Garlic, fresh                                               6.066248e-09
# Dill, fresh                                                 9.739990e-09
# Sea lettuce (Enteromorpha sp.), dried or dehydr...          4.771949e-08
#
#                                                     Effets cancéreux  \
# LCI Name
# Seaweed, agar, raw                                      6.108019e-09
# Garlic, powder, dried                                   4.343632e-10
# Garlic, fresh                                           2.824785e-10
# Dill, fresh                                             5.867577e-10
# Sea lettuce (Enteromorpha sp.), dried or dehydr...      6.108019e-09
#
#                                                     Acidification terrestre/eau douce  \
# LCI Name
# Seaweed, agar, raw                                                           0.099733
# Garlic, powder, dried                                                        0.006246
# Garlic, fresh                                                                0.002036
# Dill, fresh                                                                  0.008112
# Sea lettuce (Enteromorpha sp.), dried or dehydr...                           0.099733
#
#                                                     Eutrophisation eau douce  \
# LCI Name
# Seaweed, agar, raw                                                  0.001868
# Garlic, powder, dried                                               0.000125
# Garlic, fresh                                                       0.000069
# Dill, fresh                                                         0.000203
# Sea lettuce (Enteromorpha sp.), dried or dehydr...                  0.001868
#
#                                                     Eutrophisation marine  \
# LCI Name
# Seaweed, agar, raw                                               0.013280
# Garlic, powder, dried                                            0.002379
# Garlic, fresh                                                    0.002197
# Dill, fresh                                                      0.004050
# Sea lettuce (Enteromorpha sp.), dried or dehydr...               0.013280
#
#                                                     Eutrophisation terrestre  \
# LCI Name
# Seaweed, agar, raw                                                  0.127350
# Garlic, powder, dried                                               0.012785
# Garlic, fresh                                                       0.006394
# Dill, fresh                                                         0.031181
# Sea lettuce (Enteromorpha sp.), dried or dehydr...                  0.127350
#
#                                                     Écotoxicité eau douce  \
# LCI Name
# Seaweed, agar, raw                                              43.368466
# Garlic, powder, dried                                            5.672531
# Garlic, fresh                                                    4.064650
# Dill, fresh                                                      5.534832
# Sea lettuce (Enteromorpha sp.), dried or dehydr...              43.368466
#
#                                                     Utilisation sol  \
# LCI Name
# Seaweed, agar, raw                                        24.699395
# Garlic, powder, dried                                     20.508995
# Garlic, fresh                                             18.871203
# Dill, fresh                                               36.288833
# Sea lettuce (Enteromorpha sp.), dried or dehydr...        24.699395
#
#                                                     Épuisement ressources eau  \
# LCI Name
# Seaweed, agar, raw                                                   3.079121
# Garlic, powder, dried                                                2.585763
# Garlic, fresh                                                        3.104146
# Dill, fresh                                                          5.290335
# Sea lettuce (Enteromorpha sp.), dried or dehydr...                   3.079121
#
#                                                     Épuisement ressources énergétiques  \
# LCI Name
# Seaweed, agar, raw                                                          315.057170
# Garlic, powder, dried                                                        12.701604
# Garlic, fresh                                                                 6.275385
# Dill, fresh                                                                  12.553109
# Sea lettuce (Enteromorpha sp.), dried or dehydr...                          315.057170
#
#                                                     Épuisement ressources minéraux
# LCI Name
# Seaweed, agar, raw                                                        0.000088
# Garlic, powder, dried                                                     0.000007
# Garlic, fresh                                                             0.000004
# Dill, fresh                                                               0.000005
# Sea lettuce (Enteromorpha sp.), dried or dehydr...                        0.000088

# %% [markdown]
# Let's focus on a particular food group.

# %%
food["Sous-groupe d'aliment"].value_counts()
# Out:
# légumes                                              197
# charcuteries                                         144
# viandes crues                                        136
# céréales de petit-déjeuner et biscuits               125
# plats composés                                       122
# fromages                                             121
# viandes cuites                                       105
# boissons sans alcool                                 103
# fruits                                                98
# poissons crus                                         94
# eaux                                                  84
# produits laitiers frais et assimilés                  79
# gâteaux et pâtisseries                                76
# pains et viennoiseries                                73
# pâtes, riz et céréales                                62
# sauces                                                59
# poissons cuits                                        55
# fruits à coque et graines oléagineuses                49
# pommes de terre et autres tubercules                  46
# produits à base de poissons et produits de la mer     46
# pizzas, tartes et crêpes salées                       45
# soupes                                                43
# boisson alcoolisées                                   42
# farines et pâtes à tarte                              40
# sandwichs                                             40
# légumineuses                                          36
# chocolats et produits à base de chocolat              30
# herbes                                                24
# épices                                                23
# feuilletées et autres entrées                         22
# œufs                                                  21
# huiles et graisses végétales                          19
# ingrédients divers                                    19
# margarines                                            17
# laits                                                 17
# algues                                                16
# autres produits à base de viande                      15
# mollusques et crustacés crus                          14
# petits pots salés et plats infantiles                 13
# salades composées et crudités                         13
# laits et boissons infantiles                          12
# desserts glacés                                       12
# glaces                                                10
# beurres                                               10
# confiseries non chocolatées                            9
# confitures et assimilés                                7
# sucres, miels et assimilés                             7
# mollusques et crustacés cuits                          7
# plats végétariens                                      7
# condiments                                             7
# autres matières grasses                                6
# crèmes et spécialités à base de crème                  6
# desserts infantiles                                    5
# sels                                                   5
# substituts de viande                                   5
# huiles de poissons                                     4
# denrées destinées à une alimentation particulière      4
# sorbets                                                3
# céréales et biscuits infantiles                        3
# aides culinaires                                       3
# substituts de charcuterie                              3
# Name: Sous-groupe d'aliment, dtype: int64

# %% [markdown]
# For instance, we can pick carbs.

# %%
drinks = food[food["Sous-groupe d'aliment"] == 'boisson alcoolisées']
drinks = drinks[indicators.values()]
len(drinks)
# Out:
# 42

# %% [markdown]
# PCA finds structure in the data by studying the correlation between variables. But that doesn't mean we can't take a look at the correlation matrix to get a first understanding of the data.

# %%
import altair as alt

corr = (
    drinks
    .corr()
    .stack()
    .to_frame()
    .reset_index()
)
corr.columns = ['x', 'y', 'corr']

# Create a heatmap of the correlation matrix
heatmap = alt.Chart(corr).mark_rect().encode(
    x=alt.X('x:O', title=None),
    y=alt.Y('y:O', title=None),
    color=alt.Color('corr:Q', scale=alt.Scale(scheme='blueorange'))
)

# Create text labels for the correlation values
text = alt.Chart(corr).mark_text(baseline='middle').encode(
    x=alt.X('x:O'),
    y=alt.Y('y:O'),
    text=alt.Text('corr:Q', format='.1f'),
)

# Combine the heatmap and text labels
heatmap + text
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Clearly there are some correlations. But it's hard to see exactly what's going on. This is the value of PCA: it can help summarize a numeric dataset, which is practical when there are many columns.

# %%
import prince

pca = prince.PCA(n_components=5)
pca = pca.fit(drinks)
pca.plot(drinks, x_component=0, y_component=1)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# A good PCA is one where a small amount of components capture most of the dataset's variance. In this case it's pretty good. This means we can trust the ensueing interpretation. Indeed, four components account for >90% of the dataset's variance, even though it has 16 variables.

# %%
pca.eigenvalues_summary
# Out:
#           eigenvalue % of variance % of variance (cumulative)
# component
# 0              7.696        48.10%                     48.10%
# 1              3.350        20.94%                     69.04%
# 2              1.823        11.40%                     80.43%
# 3              1.689        10.55%                     90.99%
# 4              0.730         4.56%                     95.55%

# %% [markdown]
# We can see what variables contribute to each component. Here the first component accounts for eutrophisation and CO2. The second component has more to do with the impact on the ozone layer and thin particles.

# %%
(
    pca.column_cosine_similarities_
    .style
    .applymap(lambda x: 'background-color: yellow' if x > 0.5 else '')
)
# Out:
# <style type="text/css">
# #T_cc4ee_row0_col0, #T_cc4ee_row1_col1, #T_cc4ee_row2_col1, #T_cc4ee_row3_col1, #T_cc4ee_row4_col1, #T_cc4ee_row5_col0, #T_cc4ee_row6_col0, #T_cc4ee_row7_col0, #T_cc4ee_row8_col0, #T_cc4ee_row9_col0, #T_cc4ee_row10_col0, #T_cc4ee_row12_col0, #T_cc4ee_row15_col0 {
#   background-color: yellow;
# }
# </style>
# <table id="T_cc4ee">
#   <thead>
#     <tr>
#       <th class="index_name level0" >component</th>
#       <th id="T_cc4ee_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_cc4ee_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_cc4ee_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_cc4ee_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_cc4ee_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variable</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc4ee_level0_row0" class="row_heading level0 row0" >Changement climatique</th>
#       <td id="T_cc4ee_row0_col0" class="data row0 col0" >0.773034</td>
#       <td id="T_cc4ee_row0_col1" class="data row0 col1" >0.005659</td>
#       <td id="T_cc4ee_row0_col2" class="data row0 col2" >0.092593</td>
#       <td id="T_cc4ee_row0_col3" class="data row0 col3" >0.062739</td>
#       <td id="T_cc4ee_row0_col4" class="data row0 col4" >0.041694</td>
#     </tr>
#     <tr>
#       <th id="T_cc4ee_level0_row1" class="row_heading level0 row1" >Couche d'ozone</th>
#       <td id="T_cc4ee_row1_col0" class="data row1 col0" >0.235993</td>
#       <td id="T_cc4ee_row1_col1" class="data row1 col1" >0.618397</td>
#       <td id="T_cc4ee_row1_col2" class="data row1 col2" >0.071324</td>
#       <td id="T_cc4ee_row1_col3" class="data row1 col3" >0.034904</td>
#       <td id="T_cc4ee_row1_col4" class="data row1 col4" >0.001460</td>
#     </tr>
#     <tr>
#       <th id="T_cc4ee_level0_row2" class="row_heading level0 row2" >Rayonnements</th>
#       <td id="T_cc4ee_row2_col0" class="data row2 col0" >0.108840</td>
#       <td id="T_cc4ee_row2_col1" class="data row2 col1" >0.818837</td>
#       <td id="T_cc4ee_row2_col2" class="data row2 col2" >0.029075</td>
#       <td id="T_cc4ee_row2_col3" class="data row2 col3" >0.001843</td>
#       <td id="T_cc4ee_row2_col4" class="data row2 col4" >0.020790</td>
#     </tr>
#     <tr>
#       <th id="T_cc4ee_level0_row3" class="row_heading level0 row3" >Formation d'ozone</th>
#       <td id="T_cc4ee_row3_col0" class="data row3 col0" >0.000971</td>
#       <td id="T_cc4ee_row3_col1" class="data row3 col1" >0.513284</td>
#       <td id="T_cc4ee_row3_col2" class="data row3 col2" >0.315106</td>
#       <td id="T_cc4ee_row3_col3" class="data row3 col3" >0.100727</td>
#       <td id="T_cc4ee_row3_col4" class="data row3 col4" >0.014488</td>
#     </tr>
#     <tr>
#       <th id="T_cc4ee_level0_row4" class="row_heading level0 row4" >Particules fines</th>
#       <td id="T_cc4ee_row4_col0" class="data row4 col0" >0.023624</td>
#       <td id="T_cc4ee_row4_col1" class="data row4 col1" >0.577621</td>
#       <td id="T_cc4ee_row4_col2" class="data row4 col2" >0.378026</td>
#       <td id="T_cc4ee_row4_col3" class="data row4 col3" >0.014057</td>
#       <td id="T_cc4ee_row4_col4" class="data row4 col4" >0.000007</td>
#     </tr>
#     <tr>
#       <th id="T_cc4ee_level0_row5" class="row_heading level0 row5" >Effets non-cancéreux</th>
#       <td id="T_cc4ee_row5_col0" class="data row5 col0" >0.757044</td>
#       <td id="T_cc4ee_row5_col1" class="data row5 col1" >0.001849</td>
#       <td id="T_cc4ee_row5_col2" class="data row5 col2" >0.042602</td>
#       <td id="T_cc4ee_row5_col3" class="data row5 col3" >0.178259</td>
#       <td id="T_cc4ee_row5_col4" class="data row5 col4" >0.001951</td>
#     </tr>
#     <tr>
#       <th id="T_cc4ee_level0_row6" class="row_heading level0 row6" >Effets cancéreux</th>
#       <td id="T_cc4ee_row6_col0" class="data row6 col0" >0.825175</td>
#       <td id="T_cc4ee_row6_col1" class="data row6 col1" >0.014475</td>
#       <td id="T_cc4ee_row6_col2" class="data row6 col2" >0.082554</td>
#       <td id="T_cc4ee_row6_col3" class="data row6 col3" >0.045205</td>
#       <td id="T_cc4ee_row6_col4" class="data row6 col4" >0.003379</td>
#     </tr>
#     <tr>
#       <th id="T_cc4ee_level0_row7" class="row_heading level0 row7" >Acidification terrestre/eau douce</th>
#       <td id="T_cc4ee_row7_col0" class="data row7 col0" >0.582455</td>
#       <td id="T_cc4ee_row7_col1" class="data row7 col1" >0.130124</td>
#       <td id="T_cc4ee_row7_col2" class="data row7 col2" >0.037258</td>
#       <td id="T_cc4ee_row7_col3" class="data row7 col3" >0.185036</td>
#       <td id="T_cc4ee_row7_col4" class="data row7 col4" >0.032196</td>
#     </tr>
#     <tr>
#       <th id="T_cc4ee_level0_row8" class="row_heading level0 row8" >Eutrophisation eau douce</th>
#       <td id="T_cc4ee_row8_col0" class="data row8 col0" >0.893773</td>
#       <td id="T_cc4ee_row8_col1" class="data row8 col1" >0.002593</td>
#       <td id="T_cc4ee_row8_col2" class="data row8 col2" >0.000362</td>
#       <td id="T_cc4ee_row8_col3" class="data row8 col3" >0.000401</td>
#       <td id="T_cc4ee_row8_col4" class="data row8 col4" >0.023987</td>
#     </tr>
#     <tr>
#       <th id="T_cc4ee_level0_row9" class="row_heading level0 row9" >Eutrophisation marine</th>
#       <td id="T_cc4ee_row9_col0" class="data row9 col0" >0.928781</td>
#       <td id="T_cc4ee_row9_col1" class="data row9 col1" >0.006137</td>
#       <td id="T_cc4ee_row9_col2" class="data row9 col2" >0.007235</td>
#       <td id="T_cc4ee_row9_col3" class="data row9 col3" >0.029124</td>
#       <td id="T_cc4ee_row9_col4" class="data row9 col4" >0.000933</td>
#     </tr>
#     <tr>
#       <th id="T_cc4ee_level0_row10" class="row_heading level0 row10" >Eutrophisation terrestre</th>
#       <td id="T_cc4ee_row10_col0" class="data row10 col0" >0.590051</td>
#       <td id="T_cc4ee_row10_col1" class="data row10 col1" >0.116179</td>
#       <td id="T_cc4ee_row10_col2" class="data row10 col2" >0.014263</td>
#       <td id="T_cc4ee_row10_col3" class="data row10 col3" >0.188369</td>
#       <td id="T_cc4ee_row10_col4" class="data row10 col4" >0.040756</td>
#     </tr>
#     <tr>
#       <th id="T_cc4ee_level0_row11" class="row_heading level0 row11" >Écotoxicité eau douce</th>
#       <td id="T_cc4ee_row11_col0" class="data row11 col0" >0.172531</td>
#       <td id="T_cc4ee_row11_col1" class="data row11 col1" >0.108753</td>
#       <td id="T_cc4ee_row11_col2" class="data row11 col2" >0.282710</td>
#       <td id="T_cc4ee_row11_col3" class="data row11 col3" >0.163056</td>
#       <td id="T_cc4ee_row11_col4" class="data row11 col4" >0.164151</td>
#     </tr>
#     <tr>
#       <th id="T_cc4ee_level0_row12" class="row_heading level0 row12" >Utilisation sol</th>
#       <td id="T_cc4ee_row12_col0" class="data row12 col0" >0.782749</td>
#       <td id="T_cc4ee_row12_col1" class="data row12 col1" >0.007997</td>
#       <td id="T_cc4ee_row12_col2" class="data row12 col2" >0.033433</td>
#       <td id="T_cc4ee_row12_col3" class="data row12 col3" >0.145692</td>
#       <td id="T_cc4ee_row12_col4" class="data row12 col4" >0.001459</td>
#     </tr>
#     <tr>
#       <th id="T_cc4ee_level0_row13" class="row_heading level0 row13" >Épuisement ressources eau</th>
#       <td id="T_cc4ee_row13_col0" class="data row13 col0" >0.000208</td>
#       <td id="T_cc4ee_row13_col1" class="data row13 col1" >0.010325</td>
#       <td id="T_cc4ee_row13_col2" class="data row13 col2" >0.168375</td>
#       <td id="T_cc4ee_row13_col3" class="data row13 col3" >0.471642</td>
#       <td id="T_cc4ee_row13_col4" class="data row13 col4" >0.324813</td>
#     </tr>
#     <tr>
#       <th id="T_cc4ee_level0_row14" class="row_heading level0 row14" >Épuisement ressources énergétiques</th>
#       <td id="T_cc4ee_row14_col0" class="data row14 col0" >0.309193</td>
#       <td id="T_cc4ee_row14_col1" class="data row14 col1" >0.417673</td>
#       <td id="T_cc4ee_row14_col

# %% [markdown]
# We can then check prototypes. These are observations that are very correlated with each principal component.

# %%
pca.row_cosine_similarities(drinks).sort_values(0).tail(8)
# Out:
# component                                                  0         1  \
# LCI Name
# Whiskey-based cocktail                              0.753958  0.073643
# Wine, white, sparkling                              0.854678  0.009956
# Wine, white, sparkling, flavoured                   0.854678  0.009956
# Wine, white, dry                                    0.854678  0.009956
# Champagne                                           0.854678  0.009956
# Sparkling fruit wine                                0.927111  0.002097
# Kir (Cocktail of white wine with red fruit liqu...  0.968557  0.005857
# Champagne kir (Cocktail of champagne with red f...  0.969862  0.005311
#
# component                                                  2         3  \
# LCI Name
# Whiskey-based cocktail                              0.037128  0.071098
# Wine, white, sparkling                              0.010814  0.098537
# Wine, white, sparkling, flavoured                   0.010814  0.098537
# Wine, white, dry                                    0.010814  0.098537
# Champagne                                           0.010814  0.098537
# Sparkling fruit wine                                0.003016  0.034381
# Kir (Cocktail of white wine with red fruit liqu...  0.001516  0.006701
# Champagne kir (Cocktail of champagne with red f...  0.003370  0.002443
#
# component                                                  4
# LCI Name
# Whiskey-based cocktail                              0.001103
# Wine, white, sparkling                              0.002207
# Wine, white, sparkling, flavoured                   0.002207
# Wine, white, dry                                    0.002207
# Champagne                                           0.002207
# Sparkling fruit wine                                0.003679
# Kir (Cocktail of white wine with red fruit liqu...  0.001645
# Champagne kir (Cocktail of champagne with red f...  0.002737

# %%
pca.row_cosine_similarities(drinks).sort_values(1).tail(8)
# Out:
# component                                                  0         1  \
# LCI Name
# Liqueur                                             0.247304  0.366375
# Beer, alcohol-free (<1,2° alcohol)                  0.056102  0.831145
# Beer, strong (>8° alcohol)                          0.056102  0.831145
# Beer, low alcohol-content (3° alcohol)              0.056102  0.831145
# Beer, dark                                          0.056102  0.831145
# Beer, special (5-6° alcohol)                        0.056102  0.831145
# Beer, "specialty", from abbey or regional (vary...  0.056102  0.831145
# Beer, regular (4-5° alcohol)                        0.056102  0.831145
#
# component                                                  2         3  \
# LCI Name
# Liqueur                                             0.097338  0.215447
# Beer, alcohol-free (<1,2° alcohol)                  0.066820  0.024263
# Beer, strong (>8° alcohol)                          0.066820  0.024263
# Beer, low alcohol-content (3° alcohol)              0.066820  0.024263
# Beer, dark                                          0.066820  0.024263
# Beer, special (5-6° alcohol)                        0.066820  0.024263
# Beer, "specialty", from abbey or regional (vary...  0.066820  0.024263
# Beer, regular (4-5° alcohol)                        0.066820  0.024263
#
# component                                                  4
# LCI Name
# Liqueur                                             0.053886
# Beer, alcohol-free (<1,2° alcohol)                  0.021002
# Beer, strong (>8° alcohol)                          0.021002
# Beer, low alcohol-content (3° alcohol)              0.021002
# Beer, dark                                          0.021002
# Beer, special (5-6° alcohol)                        0.021002
# Beer, "specialty", from abbey or regional (vary...  0.021002
# Beer, regular (4-5° alcohol)                        0.021002

# %% [markdown]
# This provides an interesting insight. It seems that we have a first group with wines, and another with beers.

# %%
(
    drinks.loc['Champagne'] -
    drinks.loc['Beer, regular (4-5° alcohol)']
)
# Out:
# Changement climatique                 1.119583e-01
# Couche d'ozone                       -3.480632e-08
# Rayonnements                         -1.042852e-01
# Formation d'ozone                     2.110754e-03
# Particules fines                      1.587766e-08
# Effets non-cancéreux                  1.147933e-07
# Effets cancéreux                      1.805962e-09
# Acidification terrestre/eau douce     2.545040e-03
# Eutrophisation eau douce              1.003545e-04
# Eutrophisation marine                 5.227861e-03
# Eutrophisation terrestre              1.196195e-02
# Écotoxicité eau douce                 8.662852e+00
# Utilisation sol                       9.541839e+01
# Épuisement ressources eau             1.389024e-02
# Épuisement ressources énergétiques   -1.899935e+00
# Épuisement ressources minéraux        9.207747e-06
# dtype: float64

# %% [markdown]
# This goes with the narrative that people with wealthy habits, such as drinking champagne, pollute more than people with modest habits, such as drinking beer. Then again, one thing we haven't take into account is quantity: people usually drink less champagne than beer whenever they drink either of the two.

# %% [markdown]
# ## How does it work?

# %% [markdown]
# A PCA transforms a dataset into a new dataset with less columns. Each column in the new dataset is called a principal component. It is actually a linear combination of the columns in the original dataset. By linear combination, we mean each column contributes to a certain extent -- i.e. they are not weighted equally. Another way of saying this is that the observations are projected onto a new coordinate system.
#
# So how is this new coordinate system determined? Basically, the PCA fits an ellipsoid to the dataset. This ellipsoid is determined by the covariance matrix. The axes of the coordinate system are the eigenvectors of the dataset: these are the axes of the ellipsoid.
#
# - This blog post is quite intuitive: http://mengnote.blogspot.com/2013/05/an-intuitive-explanation-of-pca.html
# - More details are available in this excellent course by Xavier Gendre: https://www.math.univ-toulouse.fr/~xgendre/ens/l3sid/StatExplo.pdf
