# %% [markdown]
# # Skyline

# %%
import pandas as pd

url = 'https://elderscrolls.fandom.com/wiki/Bows_(Skyrim)'
tables = pd.read_html(url)
bows = tables[0]
bows
# Out:
#                                Name  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                  Ancient Nord Bow           8          12          45
# 1                        Angi's Bow           7           7          50
# 2                   Auriel's Bow DG          13          11        1000
# 3                   Bow of the Hunt          10           7         434
# 4                       Daedric Bow          19          18        2500
# 5                 Dragonbone Bow DG          20          20        2725
# 6                    Drainspell Bow          14           6         458
# 7                      Dravin's Bow           7           7          50
# 8                       Dwarven Bow          12          10         270
# 9      Dwarven Black Bow of Fate DR          13          10        1446
# 10                        Ebony Bow          17          16        1440
# 11                        Elven Bow          13          12         470
# 12                       Falmer Bow          12          15         135
# 13                Falmer Supple Bow          15          20         410
# 14                   Firiniel's End          13          12         785
# 15                     Forsworn Bow          12          11         145
# 16                      Froki's Bow           6           5         307
# 17                 Gauldur Blackbow           8          12         253
# 18                 Gauldur Blackbow           8          12         407
# 19                 Gauldur Blackbow          14          18         530
# 20                 Gauldur Blackbow          14          18         750
# 21                 Gauldur Blackbow          14          18         972
# 22                        Glass Bow          15          14         820
# 23  Glass Bow of the Stag Prince DR          16          14         375
# 24                      Hunting Bow           7           7          50
# 25                     Imperial Bow           9           8          90
# 26                    Karliah's Bow          25           9           5
# 27                         Long Bow           6           5          30
# 28                    Nord Hero Bow          11           7         200
# 29                    Nordic Bow DR          13          11         580
# 30                       Orcish Bow          10           9         150
# 31                  Stalhrim Bow DR          17          15        1800
# 32          Supple Ancient Nord Bow          14          18         235
# 33                  Nightingale Bow          12           9         493
# 34                  Nightingale Bow          13          11         838
# 35                  Nightingale Bow          15          13        1409
# 36                  Nightingale Bow          17          15        2240
# 37                  Nightingale Bow          19          18        3405
# 38                        Zephyr DG          12          10         670
#
#      Speed              Upgrade      Perk                Item ID
# 0   0.8750          Steel Ingot     Steel               000302CA
# 1   0.9370          Steel Ingot     Steel               000CC392
# 2   1.0000    Refined Moonstone     Elven               xx000800
# 3   0.9370          Steel Ingot     Steel               000AB705
# 4   0.5000          Ebony Ingot   Daedric               000139B5
# 5   0.7500          Dragon Bone    Dragon               xx0176f1
# 6   0.8750                  NaN      None               000F82FC
# 7   0.9370       Leather Strips     Steel               0006B9AD
# 8   0.7500  Dwarven Metal Ingot   Dwarven               00013995
# 9   0.7500          Ebony Ingot   Dwarven               xx02c01a
# 10  0.5620          Ebony Ingot     Ebony               000139AD
# 11  0.6870    Refined Moonstone     Elven               0001399D
# 12  0.7500       Chaurus Chitin      None               00038340
# 13  0.7500                  NaN      None               00083167
# 14  0.6870    Refined Moonstone     Elven               00017059
# 15  0.8750          Steel Ingot     Steel               000CEE9B
# 16  1.0000           Iron Ingot      None               000C0186
# 17  0.8750          Steel Ingot   Dwarven   Level 1–11: 000A5DEF
# 18  0.8750          Steel Ingot   Dwarven  Level 12–18: 000F5D1F
# 19  0.8750          Steel Ingot   Dwarven  Level 19–26: 000F5D20
# 20  0.8750          Steel Ingot   Dwarven  Level 27–35: 000F5D21
# 21  0.8750          Steel Ingot   Dwarven    Level 36+: 000F5D22
# 22  0.6250    Refined Malachite     Glass               000139A5
# 23  0.6250    Refined Malachite     Glass               xx018ed5
# 24  0.9370       Leather Strips     Steel               0010E2DD
# 25  0.7500          Steel Ingot      None               00013841
# 26  0.6250                  NaN      None               000DEED8
# 27  1.0000             Firewood      None               0003B562
# 28  0.8750          Steel Ingot      None               00068C57
# 29  0.6875    Quicksilver Ingot  Advanced               xx026232
# 30  0.8120     Orichalcum Ingot    Orcish               0001398D
# 31  0.5625             Stalhrim     Ebony               xx026231
# 32  0.8750                  NaN      None               0005D179
# 33  0.5000          Ebony Ingot      None   Level 1–18: 0007E5C3
# 34  0.5000          Ebony Ingot      None  Level 19–26: 000F6529
# 35  0.5000          Ebony Ingot      None  Level 27–35: 000F652A
# 36  0.5000          Ebony Ingot      None  Level 36–45: 000F652B
# 37  0.5000          Ebony Ingot      None    Level 46+: 000F652C
# 38  1.0000  Dwarven Metal Ingot   Dwarven               xx00cfb6

# %%
bows = bows.iloc[:, 0:5]
bows.columns = ['name', 'damage', 'weight', 'gold', 'speed']
bows.head()
# Out:
#                name  damage  weight  gold  speed
# 0  Ancient Nord Bow       8      12    45  0.875
# 1        Angi's Bow       7       7    50  0.937
# 2   Auriel's Bow DG      13      11  1000  1.000
# 3   Bow of the Hunt      10       7   434  0.937
# 4       Daedric Bow      19      18  2500  0.500

# %%
bows.corr(numeric_only=True)
# Out:
#           damage    weight      gold     speed
# damage  1.000000  0.613041  0.616495 -0.656327
# weight  0.613041  1.000000  0.573820 -0.405975
# gold    0.616495  0.573820  1.000000 -0.569465
# speed  -0.656327 -0.405975 -0.569465  1.000000

# %% [markdown]
# Insights:
#
# - The more damage, the heavier
# - The more damage, the more expensive
# - The more damage, the slower
#
# One way to simplify is to look at the damage per second (DPS) instead of the damage per hit. This is a more accurate measure of the damage output of a weapon. In our dataset, the `speed` column indicates the number of arrows fired per second, and not the time between two shots. Therefore, the DPS is simply the product of the `damage` and `speed` columns.

# %%
bows['damage_per_second'] = bows['damage'] * bows['speed']
bows.sort_values(by='damage_per_second', ascending=False).head()
# Out:
#                  name  damage  weight  gold  speed  damage_per_second
# 26      Karliah's Bow      25       9     5  0.625             15.625
# 5   Dragonbone Bow DG      20      20  2725  0.750             15.000
# 2     Auriel's Bow DG      13      11  1000  1.000             13.000
# 19   Gauldur Blackbow      14      18   530  0.875             12.250
# 20   Gauldur Blackbow      14      18   750  0.875             12.250

# %% [markdown]
# I'm not aware of a prepackaged way to calculate skylines, so we'll do it ourselves. The following implementation is naive: it iterates over the list of weapons and checks if the current weapon is dominated by any other weapon. It thus runs in $O(n^2)$ time, where $n$ is the number of weapons. There is a smarter algorithm based on block-nested loops that runs in $O(n \log n)$ time.

# %%
def a_dominates_b(a, b, to_min, to_max):

    n_better = 0

    for f in to_min:
        if a[f] > b[f]:
            return False
        n_better += a[f] < b[f]

    for f in to_max:
        if a[f] < b[f]:
            return False
        n_better += a[f] > b[f]

    if n_better > 0:
        return True
    return False


def find_skyline_brute_force(df, to_min, to_max):

    rows = df.to_dict(orient='index')
    skyline = set()

    for i in rows:
        dominated = False

        for j in rows:
            if i == j:
                continue

            if a_dominates_b(rows[j], rows[i], to_min, to_max):
                dominated = True
                break

        if not dominated:
            skyline.add(i)

    return df[df.index.isin(skyline)]

to_min = ['weight']
to_max = ['damage_per_second']

skyline = find_skyline_brute_force(
    bows,
    to_min=to_min,
    to_max=to_max
)
skyline
# Out:
#               name  damage  weight  gold  speed  damage_per_second
# 6   Drainspell Bow      14       6   458  0.875             12.250
# 16     Froki's Bow       6       5   307  1.000              6.000
# 26   Karliah's Bow      25       9     5  0.625             15.625
# 27        Long Bow       6       5    30  1.000              6.000

# %% [markdown]
# For a given bow that is part of the skyline, we can find all the bows that are worse than it.

# %%
all_worse = (
    (bows[to_min] > skyline.loc[6, to_min]).all(axis='columns') &
    (bows[to_max] < skyline.loc[6, to_max]).all(axis='columns')
)
bows[all_worse]
# Out:
#                                name  damage  weight  gold   speed  \
# 0                  Ancient Nord Bow       8      12    45  0.8750
# 1                        Angi's Bow       7       7    50  0.9370
# 3                   Bow of the Hunt      10       7   434  0.9370
# 4                       Daedric Bow      19      18  2500  0.5000
# 7                      Dravin's Bow       7       7    50  0.9370
# 8                       Dwarven Bow      12      10   270  0.7500
# 9      Dwarven Black Bow of Fate DR      13      10  1446  0.7500
# 10                        Ebony Bow      17      16  1440  0.5620
# 11                        Elven Bow      13      12   470  0.6870
# 12                       Falmer Bow      12      15   135  0.7500
# 13                Falmer Supple Bow      15      20   410  0.7500
# 14                   Firiniel's End      13      12   785  0.6870
# 15                     Forsworn Bow      12      11   145  0.8750
# 17                 Gauldur Blackbow       8      12   253  0.8750
# 18                 Gauldur Blackbow       8      12   407  0.8750
# 22                        Glass Bow      15      14   820  0.6250
# 23  Glass Bow of the Stag Prince DR      16      14   375  0.6250
# 24                      Hunting Bow       7       7    50  0.9370
# 25                     Imperial Bow       9       8    90  0.7500
# 28                    Nord Hero Bow      11       7   200  0.8750
# 29                    Nordic Bow DR      13      11   580  0.6875
# 30                       Orcish Bow      10       9   150  0.8120
# 31                  Stalhrim Bow DR      17      15  1800  0.5625
# 33                  Nightingale Bow      12       9   493  0.5000
# 34                  Nightingale Bow      13      11   838  0.5000
# 35                  Nightingale Bow      15      13  1409  0.5000
# 36                  Nightingale Bow      17      15  2240  0.5000
# 37                  Nightingale Bow      19      18  3405  0.5000
# 38                        Zephyr DG      12      10   670  1.0000
#
#     damage_per_second
# 0              7.0000
# 1              6.5590
# 3              9.3700
# 4              9.5000
# 7              6.5590
# 8              9.0000
# 9              9.7500
# 10             9.5540
# 11             8.9310
# 12             9.0000
# 13            11.2500
# 14             8.9310
# 15            10.5000
# 17             7.0000
# 18             7.0000
# 22             9.3750
# 23            10.0000
# 24             6.5590
# 25             6.7500
# 28             9.6250
# 29             8.9375
# 30             8.1200
# 31             9.5625
# 33             6.0000
# 34             6.5000
# 35             7.5000
# 36             8.5000
# 37             9.5000
# 38            12.0000

# %% [markdown]
# We can also visualize the skyline on a chart.

# %%
import altair as alt

(
    alt.Chart(
        bows
        .assign(is_skyline=lambda df: df.index.isin(skyline.index))
    )
    .mark_point()
    .encode(
        x='weight:Q',
        y='damage_per_second:Q',
        color='is_skyline:N',
        tooltip='name'
    )
    .interactive()
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Application at Carbonfact: many different materials with different variants. It's good to be able to understand what compromises are possible. Furthermore, there's no point considering a material that is worse on all aspects. Therefore a skyline is a useful tool to sift out the materials that are not worth considering.
