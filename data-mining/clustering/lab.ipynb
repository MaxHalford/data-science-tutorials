# %% [markdown]
# # Clustering lab

# %%
# !git lfs pull --include ../../data/wowah.zip

# %%
import zipfile
import pandas as pd

with zipfile.ZipFile('../../data/wowah.zip') as z:
    with z.open('wowah_data.csv') as f:
        wowah = pd.read_csv(f)
wowah
# Out:
#            char   level       race     charclass                zone   guild  \
# 0         59425       1        Orc         Rogue           Orgrimmar     165
# 1         65494       9        Orc        Hunter             Durotar      -1
# 2         65325      14        Orc       Warrior          Ghostlands      -1
# 3         65490      18        Orc        Hunter          Ghostlands      -1
# 4          2288      60        Orc        Hunter  Hellfire Peninsula      -1
# ...         ...     ...        ...           ...                 ...     ...
# 10826729  86766      80  Blood Elf  Death Knight  Halls of Lightning     101
# 10826730  86497      77  Blood Elf  Death Knight     The Storm Peaks     358
# 10826731  34893      80  Blood Elf  Death Knight     The Storm Peaks     189
# 10826732  86881      80  Blood Elf  Death Knight        Dragonblight     478
# 10826733  86457      80  Blood Elf  Death Knight        Dragonblight     204
#
#                   timestamp
# ...

# %% [markdown]
# Instructions: be creative! Use the tools we've learned so far to explore the data and find interesting patterns. You can use the clustering methods we've learned so far, or any other methods you find in scikit-learn.
#
# You will likely have to process the data in some way to get it into a form that can be used by the clustering algorithms. Indeed, there are several samples per user, so you will have to find a way to aggregate the data. Here are a couple of suggestions:
#
# 1. Look at the last sample per character, and try to cluster characters based on the basic available properties.
# 2. Add some aggregate features: the total time played, the most common time of day, the speed at which the player levelled up, etc.
# 3. Split the data into sessions, and try to cluster the sessions themselves. Transforming events into sessions is a good skill to have, as it is a common problem in data science: you have a log of events, and you want to identify meaningful sessions of activity.
